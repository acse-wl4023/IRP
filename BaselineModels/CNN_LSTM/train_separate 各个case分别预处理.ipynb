# %%
import Get_data as Gd
import copy
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from CAE import Encoder, Decoder, Autoencoder
from torchinfo import summary
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts

# %%
# 检查是否有 GPU 可用
if torch.cuda.is_available():
    print("GPU is available")
else:
    print("GPU is not available")

# 检查 GPU 的数量
num_gpus = torch.cuda.device_count()
print(f"Number of GPUs available: {num_gpus}")

# 获取每个 GPU 的名称
for i in range(num_gpus):
    print(f"GPU {i}: {torch.cuda.get_device_name(i)}")

# 设置默认使用的 GPU 设备
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# GPU is available
# Number of GPUs available: 1
# GPU 0: NVIDIA RTX A6000
# Using device: cuda:0

# %%
directory = '/data/Sibo_22Mar2024'
folders = [os.path.join(directory, f, 'hessian_') for f in os.listdir(directory) if f.startswith('case_')]

# %% [markdown]
# # CAE

# %% [markdown]
# ## Create Dataset for CAE

# %% [markdown]
# ### Use all the case

# %%
# dataset, length = Gd.get_all_nodes(folders[:-1])

# train_np, val_np = train_test_split(dataset, test_size=0.2, shuffle=True)
# train_np = np.expand_dims(train_np[:, :, 0], axis=2)
# val_np = np.expand_dims(val_np[:, :, 0], axis=2)

# %%
# preprocessor = Gd.Preprocessor()
# preprocessor.fit(train_np)

# preprocessed_train_np = preprocessor.transform(train_np)
# preprocessed_train_tensor = torch.tensor(preprocessed_train_np, dtype=torch.float).permute(0, 2, 1)
# real_train_tensor = torch.tensor(train_np, dtype=torch.float).permute(0, 2, 1)
# train_tensor_set = Gd.MyDataset(preprocessed_train_tensor, real_train_tensor)

# %%
# preprocessed_val_np = preprocessor.transform(val_np)
# preprocessed_val_tensor = torch.tensor(preprocessed_val_np, dtype=torch.float).permute(0, 2, 1)
# real_val_tensor = torch.tensor(val_np, dtype=torch.float).permute(0, 2, 1)
# val_tensor_set = Gd.MyDataset(preprocessed_val_tensor, real_val_tensor)

# %%
# train_loader = DataLoader(train_tensor_set, batch_size=5, shuffle=True)
# val_loader = DataLoader(val_tensor_set, batch_size=1, shuffle=True)

# %% [markdown]
# ### Test set

# %%
# test_np, length = Gd.get_all_nodes(folders[-1:])
# test_np = np.expand_dims(test_np[:, :, 0], axis=2)

# %%
# preprocessed_test_np = preprocessor.transform(test_np)
# preprocessed_test_tensor = torch.tensor(preprocessed_test_np, dtype=torch.float).permute(0, 2, 1)
# real_test_tensor = torch.tensor(test_np, dtype=torch.float).permute(0, 2, 1)
# val_tensor_set = Gd.MyDataset(preprocessed_test_tensor, real_test_tensor)

# %% [markdown]
# ### Preprocessed each cases

# %% [markdown]
# #### train and validation

# %%
dataset, length = Gd.get_all_nodes(folders[:-1])

dataset = np.expand_dims(dataset[:, :, 0], axis=2)
preprocessors = []
cases=[]
preprocessed_dataset_np = []

for i in range(len(length[:-1])):
    preprocessor = Gd.Preprocessor()
    preprocessor.fit(dataset[length[i]:length[i+1]])
    preprocessors.append(preprocessor)
    cases.append(np.full(length[i+1]-length[i], i))

    # preprocessed_dataset_np.append(preprocessor.transform(dataset[length[i]:length[i+1]]))

# preprocessed_dataset_np = np.concatenate(preprocessed_dataset_np, axis=0)
cases = np.concatenate(cases, axis=0)

# %%
train_np, val_np, train_cases, val_cases = train_test_split(dataset, cases, test_size=0.2, shuffle=True)

preprocessed_train_np = copy.deepcopy(train_np)
preprocessed_val_np = copy.deepcopy(val_np)

for i in range(len(train_cases)):
    preprocessed_train_np[i] = preprocessors[train_cases[i]].transform(train_np[i])

for i in range(len(val_cases)):
    preprocessed_val_np[i] = preprocessors[train_cases[i]].transform(train_np[i])

# %%
preprocessed_train_tensor = torch.tensor(preprocessed_train_np, dtype=torch.float).permute(0, 2, 1)
real_train_tensor = torch.tensor(train_np, dtype=torch.float).permute(0, 2, 1)
train_cases_tensor = torch.tensor(train_cases)

train_tensor_set = Gd.MyDataset(preprocessed_train_tensor, real_train_tensor, train_cases_tensor)

preprocessed_val_tensor = torch.tensor(preprocessed_val_np, dtype=torch.float).permute(0, 2, 1)
real_val_tensor = torch.tensor(val_np, dtype=torch.float).permute(0, 2, 1)
val_cases_tensor = torch.tensor(val_cases)

val_tensor_set = Gd.MyDataset(preprocessed_val_tensor, real_val_tensor, val_cases_tensor)

# %%
train_loader = DataLoader(train_tensor_set, batch_size=5, shuffle=True)
val_loader = DataLoader(val_tensor_set, batch_size=5, shuffle=True)

# %%
i,j,k = train_tensor_set[0]

# %% [markdown]
# #### test

# %%
test_np, test_length = Gd.get_all_nodes(folders[-1:])

test_np = np.expand_dims(test_np[:, :, 0], axis=2)
test_preprocessors = []
test_cases=[]

for i in range(len(test_length[:-1])):
    preprocessor = Gd.Preprocessor()
    preprocessor.fit(test_np[test_length[i]:test_length[i+1]])
    test_preprocessors.append(preprocessor)
    test_cases.append(np.full(test_length[i+1]-test_length[i], i))

test_cases = np.concatenate(test_cases, axis=0)

# %%
len(test_preprocessors)
# Out:
# 1

# %%
preprocessed_test_np = copy.deepcopy(test_np)

for i in range(len(test_cases)):
    preprocessed_test_np[i] = test_preprocessors[test_cases[i]].transform(test_np[i])

preprocessed_test_tensor = torch.tensor(preprocessed_test_np, dtype=torch.float).permute(0, 2, 1)
real_test_tensor = torch.tensor(test_np, dtype=torch.float).permute(0, 2, 1)
test_tensor_set = Gd.MyDataset(preprocessed_test_tensor, real_test_tensor)

# %%
preprocessed_test_tensor.max()
# Out:
# tensor(1.)

# %% [markdown]
# ## Model Info

# %%
# Create an instance of the model
encoder = Encoder(1, 50)
summary(encoder, input_size=(10, 1, 97149))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Encoder                                  [10, 50]                  --
# ├─Conv1d: 1-1                            [10, 4, 97149]            36
# ├─Dropout: 1-2                           [10, 4, 97149]            --
# ├─MaxPool1d: 1-3                         [10, 4, 19429]            --
# ├─Conv1d: 1-4                            [10, 4, 19429]            132
# ├─Dropout: 1-5                           [10, 4, 19429]            --
# ├─MaxPool1d: 1-6                         [10, 4, 3885]             --
# ├─Conv1d: 1-7                            [10, 1, 3885]             33
# ├─LeakyReLU: 1-8                         [10, 1, 3885]             --
# ├─Dropout: 1-9                           [10, 1, 3885]             --
# ├─MaxPool1d: 1-10                        [10, 1, 777]              --
# ├─AdaptiveAvgPool1d: 1-11                [10, 1, 100]              --
# ├─Flatten: 1-12                          [10, 100]                 --
# ├─Linear: 1-13                           [10, 50]                  5,050
# ==========================================================================================
# Total params: 5,251
# Trainable params: 5,251
# Non-trainable params: 0
# Total mult-adds (M): 61.95
# ==========================================================================================
# Input size (MB): 3.89
# Forward/backward pass size (MB): 37.62
# Params size (MB): 0.02
# Estimated Total Size (MB): 41.53
# ==========================================================================================

# %%
decoder = Decoder(50, 1)
summary(decoder, input_size=(10, 50))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Decoder                                  [10, 1, 97149]            --
# ├─Linear: 1-1                            [10, 512]                 26,112
# ├─Upsample: 1-2                          [10, 1, 1024]             --
# ├─Conv1d: 1-3                            [10, 1, 1018]             9
# ├─Linear: 1-4                            [10, 1, 97149]            98,994,831
# ├─Conv1d: 1-5                            [10, 1, 97149]            2
# ├─LeakyReLU: 1-6                         [10, 1, 97149]            --
# ==========================================================================================
# Total params: 99,020,954
# Trainable params: 99,020,954
# Non-trainable params: 0
# Total mult-adds (M): 992.24
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 15.67
# Params size (MB): 396.08
# Estimated Total Size (MB): 411.75
# ==========================================================================================

# %%
model = Autoencoder(1, 50)
summary(model, input_size=(10, 1, 97149))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Autoencoder                              [10, 1, 97149]            --
# ├─Encoder: 1-1                           [10, 50]                  --
# │    └─Conv1d: 2-1                       [10, 4, 97149]            36
# │    └─Dropout: 2-2                      [10, 4, 97149]            --
# │    └─MaxPool1d: 2-3                    [10, 4, 19429]            --
# │    └─Conv1d: 2-4                       [10, 4, 19429]            132
# │    └─Dropout: 2-5                      [10, 4, 19429]            --
# │    └─MaxPool1d: 2-6                    [10, 4, 3885]             --
# │    └─Conv1d: 2-7                       [10, 1, 3885]             33
# │    └─LeakyReLU: 2-8                    [10, 1, 3885]             --
# │    └─Dropout: 2-9                      [10, 1, 3885]             --
# │    └─MaxPool1d: 2-10                   [10, 1, 777]              --
# │    └─AdaptiveAvgPool1d: 2-11           [10, 1, 100]              --
# │    └─Flatten: 2-12                     [10, 100]                 --
# │    └─Linear: 2-13                      [10, 50]                  5,050
# ├─Decoder: 1-2                           [10, 1, 97149]            --
# │    └─Linear: 2-14                      [10, 512]                 26,112
# │    └─Upsample: 2-15                    [10, 1, 1024]             --
# │    └─Conv1d: 2-16                      [10, 1, 1018]             9
# │    └─Linear: 2-17                      [10, 1, 97149]            98,994,831
# │    └─Conv1d: 2-18                      [10, 1, 97149]            2
# │    └─LeakyReLU: 2-19                   [10, 1, 97149]            --
# ==========================================================================================
# Total params: 99,026,205
# Trainable params: 99,026,205
# Non-trainable params: 0
# Total mult-adds (G): 1.05
# ==========================================================================================
# Input size (MB): 3.89
# Forward/backward pass size (MB): 53.29
# Params size (MB): 396.10
# Estimated Total Size (MB): 453.28
# ==========================================================================================

# %% [markdown]
# ## Train CAE

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, y_pred, y_true):
        return torch.sqrt(self.mse(y_pred, y_true))

# %%
def train(model, train_loader, test_loader, criterion, optimizer, preprocessors, scheduler, device, epochs=30):
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        recon_train_loss = 0
        for x, real_y, cases in train_loader:
            x = x.to(device)
            optimizer.zero_grad()
            predict= model(x)
            loss = criterion(x, predict)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

            predict_np = predict.permute(0, 2, 1).cpu().detach().numpy()
            recon_predict_np = copy.deepcopy(predict_np)
            for i in range(len(cases)):
                recon_predict_np[i] = preprocessors[i].inverse_transform(predict_np[i])

            # predict_np = x.permute(0, 2, 1).cpu().detach().numpy()
            # recon_predict_np = copy.deepcopy(predict_np)
            # for i in range(len(cases)):
            #     recon_predict_np[i] = preprocessors[cases[i]].inverse_transform(predict_np[i])
            

            recon_predict_tensor = torch.tensor(recon_predict_np, dtype=torch.float).permute(0, 2, 1)
            recon_train_loss += criterion(real_y, recon_predict_tensor)

        scheduler.step()
        train_loss /= len(train_loader)
        recon_train_loss /= len(train_loader)

        model.eval()
        with torch.no_grad():
            val_loss = 0
            recon_test_loss = 0
            for x, real_y, cases in test_loader:
                x = x.to(device)
                predict= model(x)
                val_loss += criterion(x, predict).item()

                #print(criterion(output, sigmoid(data)))
                predict_np = predict.permute(0, 2, 1).cpu().detach().numpy()
                recon_predict_np = copy.deepcopy(predict_np)
                for i in range(len(cases)):
                    recon_predict_np[i] = preprocessors[cases[i]].inverse_transform(predict_np[i])
                    
                recon_predict_tensor = torch.tensor(recon_predict_np, dtype=torch.float).permute(0, 2, 1)
                recon_test_loss += criterion(real_y, recon_predict_tensor)

            val_loss /= len(test_loader)
            recon_test_loss /= len(test_loader)
        
        print(f'Epoch {epoch + 1}/{epochs}, train Loss: {train_loss}, recon train loss: {recon_train_loss}, val Loss: {val_loss}, recon val Loss: {recon_test_loss}')

# %%
model = Autoencoder(1, 50).to(device)
optimizer = optim.Adam(model.parameters())
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=5)

## SCHEDULER

criterion = RMSELoss()

train(model, train_loader, val_loader, criterion, optimizer, preprocessors, scheduler, device, epochs=20)
# 保存模型的状态字典
torch.save(model.state_dict(), 'CAE.pth')
# Out:
# Epoch 1/20, train Loss: 0.2264126038885322, recon train loss: 8.283313751220703, val Loss: 0.2098395566231218, recon val Loss: 8.213828086853027
# Epoch 2/20, train Loss: 0.1807125360737073, recon train loss: 7.890519142150879, val Loss: 0.19550595226986656, recon val Loss: 8.514039993286133
# Epoch 3/20, train Loss: 0.15874422561569973, recon train loss: 7.623891353607178, val Loss: 0.1838377560007161, recon val Loss: 8.518054962158203
# Epoch 4/20, train Loss: 0.1445623825239981, recon train loss: 7.514267921447754, val Loss: 0.18025662942693152, recon val Loss: 8.509748458862305
# Epoch 5/20, train Loss: 0.1360041236761829, recon train loss: 7.412074089050293, val Loss: 0.17583804731738978, recon val Loss: 8.590380668640137
# Epoch 6/20, train Loss: 0.13995366354055447, recon train loss: 7.515141487121582, val Loss: 0.17598296348647824, recon val Loss: 8.607413291931152
# Epoch 7/20, train Loss: 0.1258531838719701, recon train loss: 7.290771484375, val Loss: 0.15093352016190004, recon val Loss: 8.753114700317383
# Epoch 8/20, train Loss: 0.10962035038090985, recon train loss: 7.176286220550537, val Loss: 0.14516050150168353, recon val Loss: 8.776117324829102
# Epoch 9/20, train Loss: 0.0957892209789234, recon train loss: 6.911151885986328, val Loss: 0.15228285627632304, recon val Loss: 8.766929626464844
# Epoch 10/20, train Loss: 0.08769422264544871, recon train loss: 6.966193675994873, val Loss: 0.1418902544497416, recon val Loss: 8.782523155212402
# Epoch 11/20, train Loss: 0.09788487304066276, recon train loss: 6.985477447509766, val Loss: 0.14267661782174273, recon val Loss: 8.834524154663086
# Epoch 12/20, train Loss: 0.09050997886967299, recon train loss: 7.045049667358398, val Loss: 0.1398464416892364, recon val Loss: 8.773147583007812
# Epoch 13/20, train Loss: 0.07916865433598387, recon train loss: 6.935359477996826, val Loss: 0.13485019005321222, recon val Loss: 9.0297269821167
# Epoch 14/20, train Loss: 0.0697337172861243, recon train loss: 6.891376972198486, val Loss: 0.13398803532894316, recon val Loss: 8.886859893798828
# Epoch 15/20, train Loss: 0.06464782785142548, recon train loss: 6.783412456512451, val Loss: 0.1322498421088375, recon val Loss: 8.971468925476074
# Epoch 16/20, train Loss: 0.07992761870364434, recon train loss: 6.937052249908447, val Loss: 0.13889059925387645, recon val Loss: 8.832999229431152
# Epoch 17/20, train Loss: 0.07198208334438246, recon train loss: 6.86389684677124, val Loss: 0.14181109928879246, recon val Loss: 8.812074661254883
# Epoch 18/20, train Loss: 0.06529660762994197, recon train loss: 6.800841331481934, val Loss: 0.13092807853787108, recon val Loss: 8.888482093811035
# Epoch 19/20, train Loss: 0.057278119196216094, recon train loss: 6.794994831085205, val Loss: 0.13324620786668925, recon val Loss: 8.991231918334961
# Epoch 20/20, train Loss: 0.05295149783266644, recon train loss: 6.783686637878418, val Loss: 0.13163041040815157, recon val Loss: 8.963146209716797

# %% [markdown]
# ## Result

# %%
def draw_pic(model, real_x, x, real_output, preprocessors, cases, coords):
    output = model(x.to(device))

    # output.to("cpu")
    output_array = output.permute(0,2,1).cpu().detach().numpy() # [5, 1, 97149]
    recon_output = copy.deepcopy(output_array)
    for i in range(len(cases)):
        recon_output[i] = preprocessors[cases[i]].inverse_transform(output_array[i])

    fig1, axs = plt.subplots(1, 5, figsize=(30, 6))
    for i in range(len(axs)):
        axs[i].scatter(coords[:,0],coords[:,1],s = 5, c=real_x[i, :, 0], cmap='bwr')
        axs[i].set_title(f'Input {i+1}')
    plt.show()
    plt.close()

    fig2, axs = plt.subplots(1, 5, figsize=(30, 6))
    for i in range(len(axs)):
        axs[i].scatter(coords[:,0],coords[:,1],s = 5, c=recon_output[i, :, 0], cmap='bwr')
        axs[i].set_title(f'Predict {i+1}')
    plt.show()
    plt.close()

    fig3, axs = plt.subplots(1, 5, figsize=(30, 6))
    for i in range(len(axs)):
        axs[i].scatter(coords[:,0],coords[:,1],s = 5, c=real_output[i, :, 0], cmap='bwr')
        axs[i].set_title(f'Real output {i+1}')
    plt.show()
    plt.close()

# %%
xyfile = "/data/Sibo_22Mar2024/case_0/hessian_/xy_coords.npy"
xycoords_check = np.load(xyfile)

# %%
model = Autoencoder(1, 50)
# 加载保存的状态字典
state_dict = torch.load('CAE.pth')
model.load_state_dict(state_dict)
model.to(device)
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (conv1): Conv1d(1, 4, kernel_size=(8,), stride=(1,), padding=same, dilation=(2,))
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (pool1): MaxPool1d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv1d(4, 4, kernel_size=(8,), stride=(1,), padding=same, dilation=(2,))
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (pool2): MaxPool1d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv1d(4, 1, kernel_size=(8,), stride=(1,), padding=same, dilation=(2,))
#     (leaky_relu): LeakyReLU(negative_slope=0.3)
#     (dropout3): Dropout(p=0.1, inplace=False)
#     (pool3): MaxPool1d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#     (avg_pool): AdaptiveAvgPool1d(output_size=100)
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (dense): Linear(in_features=100, out_features=50, bias=True)
#   )
#   (decoder): Decoder(
#     (dense1): Linear(in_features=50, out_features=512, bias=True)
#     (upsample1): Upsample(size=1024, mode='nearest')
#     (conv1): Conv1d(1, 1, kernel_size=(8,), stride=(1,), padding=(4,), dilation=(2,))
#     (linear): Linear(in_features=1018, out_features=97149, bias=True)
#     (conv2): Conv1d(1, 1, kernel_size=(1,), stride=(1,), padding=same)
#     (leaky_relu): LeakyReLU(negative_slope=0.3)
#   )
# )

# %%
predict_test_output = model(preprocessed_test_tensor.to(device))
predict_test_output_np = predict_test_output.permute(0,2,1).cpu().detach().numpy()

recon = copy.deepcopy(predict_test_output_np)
for i in range(len(test_cases)):
    recon[i] = test_preprocessors[test_cases[i]].inverse_transform(predict_test_output_np[i])


recon = torch.tensor(recon, dtype=torch.float).permute(0,2,1)
criterion = RMSELoss()

criterion(recon, real_test_tensor).item()
print(f"reconstruct loss in test set: {criterion(recon, real_test_tensor).item()}")
# Out:
# reconstruct loss in test set: 7.360897541046143

# %%
real_x = test_np[0:5]
x = copy.deepcopy(real_x)
for i in range(len(real_x)):
    x[i] = test_preprocessors[test_cases[i]].inverse_transform(real_x[i])
x = torch.tensor(preprocessor.transform(real_x), dtype=torch.float).permute(0, 2, 1)
real_output = real_x

# %%
draw_pic(model, real_x, x, real_output, test_preprocessors, test_cases[0:5], xycoords_check)

# %% [markdown]
# # Seq2Seq

# %% [markdown]
# ## Create Dataset for Seq2Seq

# %%
CAE = Autoencoder(1, 50)
# 加载保存的状态字典
state_dict = torch.load('CAE.pth')
CAE.load_state_dict(state_dict)
CAE.to(device)
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (conv1): Conv1d(1, 4, kernel_size=(8,), stride=(1,), padding=same, dilation=(2,))
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (pool1): MaxPool1d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv1d(4, 4, kernel_size=(8,), stride=(1,), padding=same, dilation=(2,))
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (pool2): MaxPool1d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv1d(4, 1, kernel_size=(8,), stride=(1,), padding=same, dilation=(2,))
#     (leaky_relu): LeakyReLU(negative_slope=0.3)
#     (dropout3): Dropout(p=0.1, inplace=False)
#     (pool3): MaxPool1d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#     (avg_pool): AdaptiveAvgPool1d(output_size=100)
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (dense): Linear(in_features=100, out_features=50, bias=True)
#   )
#   (decoder): Decoder(
#     (dense1): Linear(in_features=50, out_features=512, bias=True)
#     (upsample1): Upsample(size=1024, mode='nearest')
#     (conv1): Conv1d(1, 1, kernel_size=(8,), stride=(1,), padding=(4,), dilation=(2,))
#     (linear): Linear(in_features=1018, out_features=97149, bias=True)
#     (conv2): Conv1d(1, 1, kernel_size=(1,), stride=(1,), padding=same)
#     (leaky_relu): LeakyReLU(negative_slope=0.3)
#   )
# )

# %% [markdown]
# ### Trainset

# %%
# train_data, length = Gd.get_all_nodes(folders[:-2]) # last two case are used to test
# train_data = np.expand_dims(train_data[:, :, 0], axis=2)
# preprocessed_train_data = preprocessor.transform(train_data)
# preprocessed_train_tensor = torch.tensor(preprocessed_train_data, dtype=torch.float).permute(0, 2, 1).to(device)

# encoded_train_data = CAE.encoder(preprocessed_train_tensor)
# encoded_train_data_np = encoded_train_data.cpu().detach().numpy()
# encoded_seq_train_data = Gd.segment_data(encoded_train_data_np, length, 10, 5)
# np.random.shuffle(encoded_seq_train_data)

# %%
# encoded_seq_train_tensor = torch.tensor(encoded_seq_train_data, dtype=torch.float)
# train_x_seq = encoded_seq_train_tensor[:, :5, :]
# train_y_seq = encoded_seq_train_tensor[:, 5:, :]

# train_set_seq = Gd.MyDataset(train_x_seq, train_y_seq)
# train_loader_seq = DataLoader(train_set_seq, batch_size=1, shuffle=True)

# %%
# train_x_seq.shape

# %% [markdown]
# ### Testset

# %%
# test_data, length = Gd.get_all_nodes(folders[-2:]) # last two case are used to test
# test_data = np.expand_dims(test_data[:, :, 0], axis=2)
# preprocessed_test_data = preprocessor.transform(test_data)
# preprocessed_test_tensor = torch.tensor(preprocessed_test_data, dtype=torch.float).permute(0, 2, 1).to(device)

# encoded_test_data = CAE.encoder(preprocessed_test_tensor)
# encoded_test_data_np = encoded_test_data.cpu().detach().numpy()
# encoded_seq_test_data = Gd.segment_data(encoded_test_data_np, length, 10, 5)
# np.random.shuffle(encoded_seq_test_data)

# %%
# encoded_seq_test_tensor = torch.tensor(encoded_seq_test_data, dtype=torch.float)
# test_x_seq = encoded_seq_test_tensor[:, :5, :]
# test_y_seq = encoded_seq_test_tensor[:, 5:, :]

# test_set_seq = Gd.MyDataset(test_x_seq, test_y_seq)
# test_loader_seq = DataLoader(test_set_seq, batch_size=5, shuffle=True)

# %% [markdown]
# ### Another way to create dataset

# %%
data, length = Gd.get_all_nodes(folders[:-2]) # last two case are used to test
data = np.expand_dims(data[:, :, 0], axis=2)
preprocessed_data = preprocessor.transform(data)
preprocessed_tensor = torch.tensor(preprocessed_data, dtype=torch.float).permute(0, 2, 1).to(device)

encoded_data = CAE.encoder(preprocessed_tensor)
encoded_data_np = encoded_data.cpu().detach().numpy()
encoded_seq_data = Gd.segment_data(encoded_data_np, length, 10, 5)

encoded_seq_train_np, encoded_seq_test_np = train_test_split(encoded_seq_data, test_size=0.2, shuffle=True)

# %%
encoded_seq_train_np.shape
# Out:
# (425, 10, 50)

# %%
encoded_seq_train_tensor = torch.tensor(encoded_seq_train_np, dtype=torch.float)
encoded_seq_test_tensor = torch.tensor(encoded_seq_test_np, dtype=torch.float)

train_x_seq = encoded_seq_train_tensor[:, :5, :]
train_y_seq = encoded_seq_train_tensor[:, 5:, :]

test_x_seq = encoded_seq_test_tensor[:, :5, :]
test_y_seq = encoded_seq_test_tensor[:, 5:, :]

train_set_seq = Gd.MyDataset(train_x_seq, train_y_seq)
train_loader_seq = DataLoader(train_set_seq, batch_size=1, shuffle=True)

test_set_seq = Gd.MyDataset(test_x_seq, test_y_seq)
test_loader_seq = DataLoader(test_set_seq, batch_size=5, shuffle=True)

# %% [markdown]
# ## Model Info

# %%
import Seq2Seq

# %%
encoder = Seq2Seq.Encoder(50, 100)
summary(encoder, input_size=(5, 5, 50))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Encoder                                  [5, 100]                  --
# ├─Linear: 1-1                            [5, 100]                  5,100
# ├─Linear: 1-2                            [5, 100]                  10,100
# ├─Sigmoid: 1-3                           [5, 100]                  --
# ├─Linear: 1-4                            [5, 100]                  5,100
# ├─Linear: 1-5                            [5, 100]                  10,100
# ├─Sigmoid: 1-6                           [5, 100]                  --
# ├─Linear: 1-7                            [5, 100]                  5,100
# ├─Linear: 1-8                            [5, 100]                  10,100
# ├─Sigmoid: 1-9                           [5, 100]                  --
# ├─Linear: 1-10                           [5, 100]                  5,100
# ├─Linear: 1-11                           [5, 100]                  10,100
# ├─Linear: 1-12                           [5, 100]                  (recursive)
# ├─Linear: 1-13                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-14                          [5, 100]                  --
# ├─Linear: 1-15                           [5, 100]                  (recursive)
# ├─Linear: 1-16                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-17                          [5, 100]                  --
# ├─Linear: 1-18                           [5, 100]                  (recursive)
# ├─Linear: 1-19                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-20                          [5, 100]                  --
# ├─Linear: 1-21                           [5, 100]                  (recursive)
# ├─Linear: 1-22                           [5, 100]                  (recursive)
# ├─Linear: 1-23                           [5, 100]                  (recursive)
# ├─Linear: 1-24                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-25                          [5, 100]                  --
# ├─Linear: 1-26                           [5, 100]                  (recursive)
# ├─Linear: 1-27                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-28                          [5, 100]                  --
# ├─Linear: 1-29                           [5, 100]                  (recursive)
# ├─Linear: 1-30                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-31                          [5, 100]                  --
# ├─Linear: 1-32                           [5, 100]                  (recursive)
# ├─Linear: 1-33                           [5, 100]                  (recursive)
# ├─Linear: 1-34                           [5, 100]                  (recursive)
# ├─Linear: 1-35                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-36                          [5, 100]                  --
# ├─Linear: 1-37                           [5, 100]                  (recursive)
# ├─Linear: 1-38                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-39                          [5, 100]                  --
# ├─Linear: 1-40                           [5, 100]                  (recursive)
# ├─Linear: 1-41                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-42                          [5, 100]                  --
# ├─Linear: 1-43                           [5, 100]                  (recursive)
# ├─Linear: 1-44                           [5, 100]                  (recursive)
# ├─Linear: 1-45                           [5, 100]                  (recursive)
# ├─Linear: 1-46                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-47                          [5, 100]                  --
# ├─Linear: 1-48                           [5, 100]                  (recursive)
# ├─Linear: 1-49                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-50                          [5, 100]                  --
# ├─Linear: 1-51                           [5, 100]                  (recursive)
# ├─Linear: 1-52                           [5, 100]                  (recursive)
# ├─Sigmoid: 1-53                          [5, 100]                  --
# ├─Linear: 1-54                           [5, 100]                  (recursive)
# ├─Linear: 1-55                           [5, 100]                  (recursive)
# ==========================================================================================
# Total params: 60,800
# Trainable params: 60,800
# Non-trainable params: 0
# Total mult-adds (M): 1.52
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.16
# Params size (MB): 0.24
# Estimated Total Size (MB): 0.41
# ==========================================================================================

# %%
decoder = Seq2Seq.Decoder(100, 50, 5)

summary(decoder, input_size=((5, 100), (5, 100), (5, 100)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Decoder                                  [5, 5, 50]                --
# ├─Linear: 1-1                            [5, 50]                   5,050
# ├─Linear: 1-2                            [5, 50]                   5,050
# ├─Linear: 1-3                            [5, 50]                   5,050
# ├─Linear: 1-4                            [5, 50]                   2,550
# ├─Sigmoid: 1-5                           [5, 50]                   --
# ├─Linear: 1-6                            [5, 50]                   5,050
# ├─Linear: 1-7                            [5, 50]                   2,550
# ├─Sigmoid: 1-8                           [5, 50]                   --
# ├─Linear: 1-9                            [5, 50]                   5,050
# ├─Linear: 1-10                           [5, 50]                   2,550
# ├─Sigmoid: 1-11                          [5, 50]                   --
# ├─Linear: 1-12                           [5, 50]                   5,050
# ├─Linear: 1-13                           [5, 50]                   2,550
# ├─Linear: 1-14                           [5, 50]                   (recursive)
# ├─Linear: 1-15                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-16                          [5, 50]                   --
# ├─Linear: 1-17                           [5, 50]                   (recursive)
# ├─Linear: 1-18                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-19                          [5, 50]                   --
# ├─Linear: 1-20                           [5, 50]                   (recursive)
# ├─Linear: 1-21                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-22                          [5, 50]                   --
# ├─Linear: 1-23                           [5, 50]                   (recursive)
# ├─Linear: 1-24                           [5, 50]                   (recursive)
# ├─Linear: 1-25                           [5, 50]                   (recursive)
# ├─Linear: 1-26                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-27                          [5, 50]                   --
# ├─Linear: 1-28                           [5, 50]                   (recursive)
# ├─Linear: 1-29                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-30                          [5, 50]                   --
# ├─Linear: 1-31                           [5, 50]                   (recursive)
# ├─Linear: 1-32                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-33                          [5, 50]                   --
# ├─Linear: 1-34                           [5, 50]                   (recursive)
# ├─Linear: 1-35                           [5, 50]                   (recursive)
# ├─Linear: 1-36                           [5, 50]                   (recursive)
# ├─Linear: 1-37                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-38                          [5, 50]                   --
# ├─Linear: 1-39                           [5, 50]                   (recursive)
# ├─Linear: 1-40                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-41                          [5, 50]                   --
# ├─Linear: 1-42                           [5, 50]                   (recursive)
# ├─Linear: 1-43                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-44                          [5, 50]                   --
# ├─Linear: 1-45                           [5, 50]                   (recursive)
# ├─Linear: 1-46                           [5, 50]                   (recursive)
# ├─Linear: 1-47                           [5, 50]                   (recursive)
# ├─Linear: 1-48                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-49                          [5, 50]                   --
# ├─Linear: 1-50                           [5, 50]                   (recursive)
# ├─Linear: 1-51                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-52                          [5, 50]                   --
# ├─Linear: 1-53                           [5, 50]                   (recursive)
# ├─Linear: 1-54                           [5, 50]                   (recursive)
# ├─Sigmoid: 1-55                          [5, 50]                   --
# ├─Linear: 1-56                           [5, 50]                   (recursive)
# ├─Linear: 1-57                           [5, 50]                   (recursive)
# ==========================================================================================
# Total params: 40,500
# Trainable params: 40,500
# Non-trainable params: 0
# Total mult-adds (M): 0.81
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.08
# Params size (MB): 0.16
# Estimated Total Size (MB): 0.25
# ==========================================================================================

# %%
model = Seq2Seq.Seq2Seq(50, 100, 50, 5)
summary(model, input_size=(5, 5, 50))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Seq2Seq                                  [5, 5, 50]                --
# ├─Encoder: 1-1                           [5, 100]                  --
# │    └─Linear: 2-1                       [5, 100]                  5,100
# │    └─Linear: 2-2                       [5, 100]                  10,100
# │    └─Sigmoid: 2-3                      [5, 100]                  --
# │    └─Linear: 2-4                       [5, 100]                  5,100
# │    └─Linear: 2-5                       [5, 100]                  10,100
# │    └─Sigmoid: 2-6                      [5, 100]                  --
# │    └─Linear: 2-7                       [5, 100]                  5,100
# │    └─Linear: 2-8                       [5, 100]                  10,100
# │    └─Sigmoid: 2-9                      [5, 100]                  --
# │    └─Linear: 2-10                      [5, 100]                  5,100
# │    └─Linear: 2-11                      [5, 100]                  10,100
# │    └─Linear: 2-12                      [5, 100]                  (recursive)
# │    └─Linear: 2-13                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-14                     [5, 100]                  --
# │    └─Linear: 2-15                      [5, 100]                  (recursive)
# │    └─Linear: 2-16                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-17                     [5, 100]                  --
# │    └─Linear: 2-18                      [5, 100]                  (recursive)
# │    └─Linear: 2-19                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-20                     [5, 100]                  --
# │    └─Linear: 2-21                      [5, 100]                  (recursive)
# │    └─Linear: 2-22                      [5, 100]                  (recursive)
# │    └─Linear: 2-23                      [5, 100]                  (recursive)
# │    └─Linear: 2-24                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-25                     [5, 100]                  --
# │    └─Linear: 2-26                      [5, 100]                  (recursive)
# │    └─Linear: 2-27                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-28                     [5, 100]                  --
# │    └─Linear: 2-29                      [5, 100]                  (recursive)
# │    └─Linear: 2-30                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-31                     [5, 100]                  --
# │    └─Linear: 2-32                      [5, 100]                  (recursive)
# │    └─Linear: 2-33                      [5, 100]                  (recursive)
# │    └─Linear: 2-34                      [5, 100]                  (recursive)
# │    └─Linear: 2-35                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-36                     [5, 100]                  --
# │    └─Linear: 2-37                      [5, 100]                  (recursive)
# │    └─Linear: 2-38                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-39                     [5, 100]                  --
# │    └─Linear: 2-40                      [5, 100]                  (recursive)
# │    └─Linear: 2-41                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-42                     [5, 100]                  --
# │    └─Linear: 2-43                      [5, 100]                  (recursive)
# │    └─Linear: 2-44                      [5, 100]                  (recursive)
# │    └─Linear: 2-45                      [5, 100]                  (recursive)
# │    └─Linear: 2-46                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-47                     [5, 100]                  --
# │    └─Linear: 2-48                      [5, 100]                  (recursive)
# │    └─Linear: 2-49                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-50                     [5, 100]                  --
# │    └─Linear: 2-51                      [5, 100]                  (recursive)
# │    └─Linear: 2-52                      [5, 100]                  (recursive)
# │    └─Sigmoid: 2-53                     [5, 100]                  --
# │    └─Linear: 2-54                      [5, 100]                  (recursive)
# │    └─Linear: 2-55                      [5, 100]                  (recursive)
# ├─Decoder: 1-2                           [5, 5, 50]                --
# │    └─Linear: 2-56                      [5, 50]                   5,050
# │    └─Linear: 2-57                      [5, 50]                   5,050
# │    └─Linear: 2-58                      [5, 50]                   5,050
# │    └─Linear: 2-59                      [5, 50]                   2,550
# │    └─Sigmoid: 2-60                     [5, 50]                   --
# │    └─Linear: 2-61                      [5, 50]                   5,050
# │    └─Linear: 2-62                      [5, 50]                   2,550
# │    └─Sigmoid: 2-63                     [5, 50]                   --
# │    └─Linear: 2-64                      [5, 50]                   5,050
# │    └─Linear: 2-65                      [5, 50]                   2,550
# │    └─Sigmoid: 2-66                     [5, 50]                   --
# │    └─Linear: 2-67                      [5, 50]                   5,050
# │    └─Linear: 2-68                      [5, 50]                   2,550
# │    └─Linear: 2-69                      [5, 50]                   (recursive)
# │    └─Linear: 2-70                      [5, 50]                   (recursive)
# │    └─Sigmoid: 2-71                     [5, 50]                   --
# │    └─Linear: 2-72                      [5, 50]                   (recursive)
# │    └─Linear: 2-73                      [5, 50]                   (recursive)
# │    └─Sigmoid: 2-74                     [5, 50]                   --
# │    └─Linear: 2-75                      [5, 50]                   (recursive)
# │    └─Linear: 2-76                      [5, 50]                   (recursive)
# │    └─Sigmoid: 2-77                     [5, 50]                   --
# │    └─Linear: 2-78                      [5, 50]                   (recursive)
# │    └─Linear: 2-79                      [5, 50]                   (recursive)
# │    └─Linear: 2-80                      [5, 50]                   (recursive)
# │    └─Linear: 2-81                      [5, 50]                   (recursive)
# │    └─Sigmoid: 2-82                     [5, 50]                   --
# │    └─Linear: 2-83                      [5, 50]                   (recursive)
# │    └─Linear: 2-84                      [5, 50]                   (recursive)
# │    └─Sigmoid: 2-85                     [5, 50]                   --
# │    └─Linear: 2-86                      [5, 50]                   (recursive)
# │    └─Linear: 2-87                      [5, 50]                   (recursive)
# │    └─Sigmoid: 2-88                     [5, 50]                   --
# │    └─Linear: 2-89                      [5, 50]                   (recursive)
# │    └─Linear: 2-90                      [5, 50]                   (recursive)
# │    └─Linear: 2-91                      [5, 50]                   (recursive)
# │    └─Linear: 2-92                      [5, 50]                   (recursive)
# │    └─Sigmoid: 2-93                     [5, 50]                   --
# │    └─Linear: 2-94                      [5, 50]                   (recursive)
# │    └─Linear: 2-95                      [5, 50]                   (recursive)
# │    └─Sigmoid: 2-96                     [5, 50]                   --
# │    └─Linear: 2-97                      [5, 50]                   (recursive)
# │    └─Linear: 2-98                      [5, 50]                   (recursive)
# │    └─Sigmoid: 2-99                     [5, 50]                   --
# │    └─Linear: 2-100                     [5, 50]                   (recursive)
# │    └─Linear: 2-101                     [5, 50]                   (recursive)
# │    └─Linear: 2-102                     [5, 50]                   (recursive)
# │    └─Linear: 2-103                     [5, 50]                   (recursive)
# │    └─Sigmoid: 2-104                    [5, 50]                   --
# │    └─Linear: 2-105                     [5, 50]                   (recursive)
# │    └─Linear: 2-106                     [5, 50]                   (recursive)
# │    └─Sigmoid: 2-107                    [5, 50]                   --
# │    └─Linear: 2-108                     [5, 50]                   (recursive)
# │    └─Linear: 2-109                     [5, 50]                   (recursive)
# │    └─Sigmoid: 2-110                    [5, 50]                   --
# │    └─Linear: 2-111                     [5, 50]                   (recursive)
# │    └─Linear: 2-112                     [5, 50]                   (recursive)
# ├─LeakyReLU: 1-3                         [5, 5, 50]                --
# ==========================================================================================
# Total params: 101,300
# Trainable params: 101,300
# Non-trainable params: 0
# Total mult-adds (M): 2.33
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.24
# Params size (MB): 0.41
# Estimated Total Size (MB): 0.65
# ==========================================================================================

# %% [markdown]
# ## Train Seq2Seq

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, y_pred, y_true):
        return torch.sqrt(self.mse(y_pred, y_true))

# %%
def train(model, train_loader, test_loader, criterion, optimizer, device, epochs=30):
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            predict= model(x)
            loss = criterion(y, predict)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)

        model.eval()
        with torch.no_grad():
            val_loss = 0
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                predict= model(x)
                val_loss += criterion(y, predict).item()


            val_loss /= len(test_loader)
        
        print(f'Epoch {epoch + 1}/{epochs}, train Loss: {train_loss}, val Loss: {val_loss}')

# %%
model = Seq2Seq.Seq2Seq(50, 100, 50, 5).to(device)
optimizer = optim.Adam(model.parameters())
criterion = RMSELoss()

train(model, train_loader_seq, test_loader_seq, criterion, optimizer, device)
# 保存模型的状态字典
torch.save(model.state_dict(), 'Seq2Seq.pth')
# Out:
# Epoch 1/30, train Loss: 0.16843753455316318, val Loss: 0.17829804494976997
# Epoch 2/30, train Loss: 0.1513306620541741, val Loss: 0.17407794703136792
# Epoch 3/30, train Loss: 0.14883407877648577, val Loss: 0.17013207585974174
# Epoch 4/30, train Loss: 0.14679558380561716, val Loss: 0.16546527431769806
# Epoch 5/30, train Loss: 0.14611056296264424, val Loss: 0.1638170931149613
# Epoch 6/30, train Loss: 0.14545844650443862, val Loss: 0.1722517961805517
# Epoch 7/30, train Loss: 0.14492935618933508, val Loss: 0.16514045965265145
# Epoch 8/30, train Loss: 0.14441620239440134, val Loss: 0.169197696515105
# Epoch 9/30, train Loss: 0.14423256922294111, val Loss: 0.1661310920661146
# Epoch 10/30, train Loss: 0.14386819583528182, val Loss: 0.168866253034635
# Epoch 11/30, train Loss: 0.14352940084303126, val Loss: 0.1644303910434246
# Epoch 12/30, train Loss: 0.14338864119613873, val Loss: 0.1649038578298959
# Epoch 13/30, train Loss: 0.14274520289371995, val Loss: 0.16418069634925236
# Epoch 14/30, train Loss: 0.14286658848033232, val Loss: 0.16649613631042567
# Epoch 15/30, train Loss: 0.14260232067283463, val Loss: 0.16721341928297823
# Epoch 16/30, train Loss: 0.1425106271400171, val Loss: 0.16835226626558739
# Epoch 17/30, train Loss: 0.14223188312614665, val Loss: 0.16450156745585529
# Epoch 18/30, train Loss: 0.14190030575675122, val Loss: 0.16311305795203557
# Epoch 19/30, train Loss: 0.14170075340306057, val Loss: 0.16848095811226152
# Epoch 20/30, train Loss: 0.14148394160410938, val Loss: 0.1665294302458113
# Epoch 21/30, train Loss: 0.14139790065148297, val Loss: 0.16627653383395888
# Epoch 22/30, train Loss: 0.14125750220873776, val Loss: 0.16614411974495108
# Epoch 23/30, train Loss: 0.14088984719970646, val Loss: 0.16668820550495927
# Epoch 24/30, train Loss: 0.14055256154607323, val Loss: 0.1675432805310596
# Epoch 25/30, train Loss: 0.1402659066459712, val Loss: 0.1661845547231761
# Epoch 26/30, train Loss: 0.1400040672368863, val Loss: 0.16365932148288598
# Epoch 27/30, train Loss: 0.13974688884966513, val Loss: 0.1662860827689821
# Epoch 28/30, train Loss: 0.1396131264812806, val Loss: 0.16754695536060768
# Epoch 29/30, train Loss: 0.13959813657928916, val Loss: 0.16430409896102818
# Epoch 30/30, train Loss: 0.1391125947061707, val Loss: 0.16985059123147617

# %% [markdown]
# # Validation

# %%
CAE = Autoencoder(1, 50)
# 加载保存的状态字典
state_dict = torch.load('CAE.pth')
CAE.load_state_dict(state_dict)
CAE.to(device)

Seq2Seq = Seq2Seq.Seq2Seq(50, 100, 50, 5)
# 加载保存的状态字典
state_dict = torch.load('Seq2Seq.pth')
Seq2Seq.load_state_dict(state_dict)
Seq2Seq.to(device)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (sigmoid): Sigmoid()
#     (W_xi): Linear(in_features=50, out_features=100, bias=True)
#     (W_hi): Linear(in_features=100, out_features=100, bias=True)
#     (W_xf): Linear(in_features=50, out_features=100, bias=True)
#     (W_hf): Linear(in_features=100, out_features=100, bias=True)
#     (W_xo): Linear(in_features=50, out_features=100, bias=True)
#     (W_ho): Linear(in_features=100, out_features=100, bias=True)
#     (W_xc): Linear(in_features=50, out_features=100, bias=True)
#     (W_hc): Linear(in_features=100, out_features=100, bias=True)
#   )
#   (decoder): Decoder(
#     (sigmoid): Sigmoid()
#     (W_xi): Linear(in_features=100, out_features=50, bias=True)
#     (W_hi): Linear(in_features=50, out_features=50, bias=True)
#     (W_xf): Linear(in_features=100, out_features=50, bias=True)
#     (W_hf): Linear(in_features=50, out_features=50, bias=True)
#     (W_xo): Linear(in_features=100, out_features=50, bias=True)
#     (W_ho): Linear(in_features=50, out_features=50, bias=True)
#     (W_xc): Linear(in_features=100, out_features=50, bias=True)
#     (W_hc): Linear(in_features=50, out_features=50, bias=True)
#     (ini_h): Linear(in_features=100, out_features=50, bias=True)
#     (ini_c): Linear(in_features=100, out_features=50, bias=True)
#   )
#   (leakyrelu): LeakyReLU(negative_slope=0.1)
# )

# %% [markdown]
# ## Get data

# %%
val_data, length = Gd.get_all_nodes(folders[-2:])
val_data = np.expand_dims(val_data[:, :, 0], axis=2)

# %%
preprocessed_tensor = torch.tensor(preprocessed_data, dtype=torch.float).permute(0, 2, 1).to(device)

encoded_data = CAE.encoder(preprocessed_tensor)
encoded_data_np = encoded_data.cpu().detach().numpy()
encoded_seq_data = Gd.segment_data(encoded_data_np, length, 10, 5)

encoded_seq_train_np, encoded_seq_test_np = train_test_split(encoded_seq_data, test_size=0.2, shuffle=True)

# %%
val_data.shape
# Out:
# (200, 97149, 1)
